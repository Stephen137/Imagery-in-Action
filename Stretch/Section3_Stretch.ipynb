# %% [markdown]
# ### **Stretch goal (optional)**

# %% [markdown]
# Throughout this course, you will have the opportunity to complete stretch goals. These goals allow you to continue or enhance the work that you completed during the exercise.
#
# Stretch goals are community-supported (meaning that your fellow MOOC participants can assist you with the steps to complete the stretch goal using the Lesson Forum), and they are a great opportunity to work together to learn.
#
# 1. In a web browser, go to the [Subdivision Progress 3D Mesh](https://www.arcgis.com/home/item.html?id=f4089c2d183542c0bb4f96d278043dcb) scene layer.
#
# > Note: The complete URL for this layer is https://www.arcgis.com/home/item.html?id=f4089c2d183542c0bb4f96d278043dcb.
#
# 2. Click Open In Scene Viewer.
#
# 3. Use the `tools provided on the toolbar`, in the upper-right corner of the scene, to answer all or some of the following questions:
#
# >Q1. What is the average height of the tallest home in the scene?
#
# ![tallest_house.JPG](attachment:4f43ba1b-1d35-401a-b4eb-085188b60f3e.JPG)
#
# >A1. The home with the orange buffer relates to the highest point on the elevation profile. The elevation of the home is 217.4m and after we deduct the ground elevaton of 209.2m we obtain the height of the home - 8.2m.
#
#
# >Q2. Which house has the largest fenced-in yard?
#
# ![biggest_yard.JPG](attachment:35a6e823-e00b-4c0b-9a87-c871cfef70ad.JPG)
#
# >A2. See above graphic. Total crosshatched area is 608.66 metres squared. This is larger than any of the other yards I calculated for.
#
# >Q3. When the shadows are enabled, which houses have shaded backyards on August 25, 2023, at 4:00 PM, Central Time (UTC-6 CST - US and Canada)?
#
# ![shaded_backyards.JPG](attachment:9773f2a0-6ffc-4ff6-b023-277ffadb2a27.JPG)
#
# >Q4. Which house has the driveway with the most area, and what is the measurement?
#
# ![driveway_area.JPG](attachment:6bf4b502-f6de-44d3-8e5b-1eee174272eb.JPG)
#
# >A4. The home with the crosshatched driveway indicating a driveway area of 70.8 metres squared.
#
#
# For more information about Scene Viewer, go to ArcGIS Online Help: [Get started with Scene Viewer](https://doc.arcgis.com/en/arcgis-online/get-started/view-scenes.htm) and [Scene navigation](https://doc.arcgis.com/en/arcgis-online/get-started/navigate-scene.htm).
#
# 4. When you are finished, close the web browser.
#
# 5. Use the Lesson Forum to post your questions, observations, and screen capture examples to identify which homes best represent the answers.
#
# > Note: Be sure to include the #stretch hashtag in the posting title.

# %% [markdown]
# ### Improvements / Thoughts

# %% [markdown]
# I particularly liked the weather features. I can see the utility of this feature when deciding which plot to buy -  a great way to identify sun traps for hosting BBQs, growing fruit or veg etc.

# %% [markdown]
# Just hit `CTRL + E` and boom :

# %%
from IPython.display import Video

Video("shadows.mp4")
# Out:
# <video src="shadows.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# See [other keyboard shortcuts](https://doc.arcgis.com/en/arcgis-online/get-started/navigate-scene.htm).

# %% [markdown]
# Whilst the `Analyse` tool is excellent for calculating lengths, perimeters, and area, this does still require a fair amount of manual work. Consider harnessing deep learning for object detection to automate the isolation of homes, driveways and fenced yards.
